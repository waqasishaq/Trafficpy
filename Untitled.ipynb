# %%
import requests
import json
from pprint import pprint

# %%
base2 = "https://api.tomtom.com/routing/1/calculateRoute/40.349260,-74.313781:40.534631,-74.519930/json?"
white = {
    "key": "BWvoBdPFvw85nOlFbGDQalUgoi4v2c0J",
#     "departAt":"2018-07-31T16:30:00",
    "departAt":"now",
    
    "traffic":"true"
}

response2 = requests.get(base2, params=white).json()
pprint(response2)
# Out:
# {'copyright': 'Copyright 2018 TomTom International BV. All rights reserved. '
#               'This navigation data is the proprietary copyright of TomTom '
#               'International BV and may be used only in accordance with the '
#               'terms of a fully executed license agreement entered into '
#               'between TomTom International BV, or an authorised reseller and '
#               'yourself. If you have not entered into such a license agreement '
#               'you are not authorised to use this data in any manner and '
#               'should immediately return it to TomTom International BV.',
#  'formatVersion': '0.0.12',
#  'privacy': 'TomTom keeps information that tells us how and when you use our '
#             'services. This includes information about the device you are '
#             'using and the information we receive while you use the service, '
#             'such as locations, routes, destinations and search queries. '
# ...

# %%
base3 = "https://route.cit.api.here.com/routing/7.2/calculateroute.json?"
black = {
    "app_id": "0rdpOuUVfVIhXyw8yD4C",
    "app_code":"xNzmz4MnxXNzlWkotEqy9w",
    "mode":"fastest;car;traffic:enabled",
    "waypoint0":"geo!40.349260,-74.313781",
    "waypoint1":"geo!40.534631,-74.519930",
    "departure":"now",
    "routeattributes":"sh,bb,gr"

}

response2 = requests.get(base3, params=black).json()
pprint(response2)
# Out:
# {'response': {'language': 'en-us',
#               'metaInfo': {'availableMapVersion': ['8.30.84.157'],
#                            'interfaceVersion': '2.6.34',
#                            'mapVersion': '8.30.84.157',
#                            'moduleVersion': '7.2.201825-29488',
#                            'timestamp': '2018-06-29T00:12:17Z'},
#               'route': [{'boundingBox': {'bottomRight': {'latitude': 40.3492734,
#                                                          'longitude': -74.2934883},
#                                          'topLeft': {'latitude': 40.5579615,
#                                                      'longitude': -74.5229781}},
#                          'leg': [{'end': {'label': 'Atrium Dr',
#                                           'linkId': '-1128122523',
#                                           'mappedPosition': {'latitude': 40.5346155,
#                                                              'longitude': -74.5199203},
# ...

# %%
import datetime
# Out:
# '1530532800'

# %%
base4 = "https://maps.googleapis.com/maps/api/distancematrix/json?"
blue = {
    "key": "AIzaSyClUQ2ca81McBm42Z5siXFRUFuDcQZccY4",
    "origins":"147 serpentine dr morganville nj",
    "destinations":"300 atrium drive somerset nj",
    "units":"imperial",
    "traffic_model":"best_guess",
    "departure_time":timestamp

}

response2 = requests.get(base4, params=blue).json()
pprint(response2)
# Out:
# {'destination_addresses': ['300 Atrium Dr, Somerset, NJ 08873, USA'],
#  'origin_addresses': ['147 Serpentine Dr, Morganville, NJ 07751, USA'],
#  'rows': [{'elements': [{'distance': {'text': '20.2 mi', 'value': 32451},
#                          'duration': {'text': '36 mins', 'value': 2177},
#                          'duration_in_traffic': {'text': '51 mins',
#                                                  'value': 3032},
#                          'status': 'OK'}]}],
#  'status': 'OK'}

# %%
dt = datetime(2018, 6, 29, 4, 48, 0)
timestamp = (dt - datetime(1970, 1, 1)).total_seconds()
print(timestamp)
# Out:
# 1530247680.0

# %%
response2["rows"][0]["elements"][0]["duration"]["value"]
# Out:
# 2177

# %%
base4 = "https://maps.googleapis.com/maps/api/directions/json?"
blue = {
    "key": "AIzaSyClUQ2ca81McBm42Z5siXFRUFuDcQZccY4",
    "origin":"147 serpentine dr morganville nj",
    "destination":"300 atrium drive somerset nj",
    "units":"imperial",
    "traffic_model":"best_guess",
    "departure_time":timestamp

}

response2 = requests.get(base4, params=blue).json()
pprint(response2)
# Out:
# {'destination_addresses': ['300 Atrium Dr, Somerset, NJ 08873, USA'],
#  'origin_addresses': ['147 Serpentine Dr, Morganville, NJ 07751, USA'],
#  'rows': [{'elements': [{'distance': {'text': '20.2 mi', 'value': 32451},
#                          'duration': {'text': '36 mins', 'value': 2177},
#                          'duration_in_traffic': {'text': '51 mins',
#                                                  'value': 3032},
#                          'status': 'OK'}]}],
#  'status': 'OK'}
